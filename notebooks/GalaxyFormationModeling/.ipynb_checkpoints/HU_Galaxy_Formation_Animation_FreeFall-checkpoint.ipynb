# %%
# !pip install git+https://github.com/jupyterhub/binderhub
# !pip install https://github.com/jupyter/repo2docker/archive/master.zip

# %% [markdown]
# # ANGULAR SIZE VERSUS Z
#
# In HU, the distance is given by
# $d(z) = R_0 \frac{z}{(1+z)}$
#
# the 4D radius is given by:
# $R(z) = R_0 \frac{1}{(1+z)}$
#
# where $R_0$ = 14.01 GLY
# $G(t) = G_0\frac{R_0}{R(z)}$
#
# $G = G_0 (1+z)$
#
# Using Newtonian Dynamics while reversing time (having the average galaxy moving back in time and through the 4D spatial manifold), we get:
# $G(z)\frac{M}{r(z)^2} = \frac{v(z)^2}{r(z)}$
#
# r(z)=$G(z)\frac{M}{v(z)^2}=G_0 (1+z)\frac{M}{v(z)^2}$
#
# Since the angular size of a galaxy is roughly r(z)/d(z)
#
# AngularSize= $G_0 (1+z)\frac{M}{v(z)^2}/(R_0\frac{z}{(1+z)})= \frac{G_0M(1+z)^2}{R_0  z v(z)^2} \propto \frac{1}{z}$
#
# This means that v(z) =$ v_0(1+z)$ which implies that $r(z) = r_0/(1+z)$
#
# where $R_0$ is the current 4D radius (14.01 GLY), and $v_0$ is the current tangential velocity of a body in orbit.
#
# So, as G varies, the radius of the orbits varies, and velocity adjusts to keep angular momentum constant. The resulting angular size z-dependency is $\frac{1}{z} $as depicted in Kapahi’s data.
#
# **NOTICE THAT THIS IS NOT A SMALL RESULT. I DERIVED THE Z-DEPENDENCY OF THE ANGULAR SIZE (AN OBSERVABLE) IN AN EPOCH-DEPENDENT G. THIS HAS NEVER BEEN DONE, AND IT SUPPORTS MY THEORY AND DEBUNKS GENERAL RELATIVITY.**
#
# **JWST'S OBSERVATION OF HUGE GALAXIES IS THE RESULT OF INCORRECT GALAXY SIZE PREDICTIONS AND DISTRIBUTION DUE TO RIEMMANIAN GEOMETRY: NO IFS OR BUTS.**

# %%
import matplotlib
# matplotlib.use('TkAgg')  # Use the TkAgg backend (or another appropriate one)
import matplotlib.pyplot as plt
import numpy as np
import math
import xarray as xr
import pandas as pd
from hugalaxy import GalaxyWrapper, plotRotationCurve, calculate_density_parameters, move_rotation_curve
from timeit import default_timer as timer
import jupyter_to_medium as medium


import ipywidgets as widgets
from timeit import default_timer as timer
from IPython.display import display, HTML
import matplotlib.gridspec as gridspec
import matplotlib.animation as animation
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D  # This import registers the 3D projection
from matplotlib.animation import FuncAnimation
import astropy.constants as cc
M_sun = cc.M_sun
M_sun

####################################################
# MODELING M33 GALAXY
####################################################

m33_rotational_curve = np.array( [
    [0.0, 0.0],
    [1508.7187, 38.674137],
    [2873.3889, 55.65067],
    [4116.755, 67.91063],
    [5451.099, 79.22689],
    [6846.0957, 85.01734],
    [8089.462, 88.38242],
    [9393.48, 92.42116],
    [10727.824, 95.11208],
    [11880.212, 98.342697],
    [13275.208, 99.82048],
    [14609.553, 102.10709],
    [18521.607, 104.25024],
    [22403.336, 107.60643],
    [26406.369, 115.40966],
    [30379.076, 116.87875],
    [34382.107, 116.05664],
    [38354.813, 117.93005],
    [42266.87, 121.42091],
    [46300.227, 128.55017],
    [50212.285, 132.84966]
])

M33_Distance = 3.2E6
Radius_Universe_4D = 14.03E9
redshift0 = M33_Distance / (Radius_Universe_4D - M33_Distance)
redshift = 10
nr = 160
# NZ should always be ODD
nz = 101
ntheta = 180
R_max = 50000.0

rho_0, alpha_0, rho_1, alpha_1, h0 = calculate_density_parameters(redshift)
GalaxyMass = 5E10
# Create The Galaxy
M33 = GalaxyWrapper(GalaxyMass, rho_0, alpha_0, rho_1, alpha_1, h0, R_max, nr,
                    nz, ntheta, redshift,GPU_ID=0, cuda=True, taskflow=True)
new_m33_rotational_curve = move_rotation_curve(m33_rotational_curve, redshift0, redshift)
M33.read_galaxy_rotation_curve(new_m33_rotational_curve)
eta = 1E-2
temperature = 7
current_time = 14E9/(1+M33.redshift)
time_step_years = 100E3
n_epochs = 15
final_time = current_time + n_epochs * time_step_years
epochs = np.geomspace(current_time, final_time, n_epochs)
redshifts = pd.DataFrame(14.1E9/epochs -1)
filename_base = "./data/"
M33.FreeFallGalaxyFormation(epochs,filename_base)
# Out:
# There are no NaNs in the array.
# There are no NaNs in the current_masses array at epoch 1.
# FreeFall Simulation redshift 10 - total mass of galaxy = 24.9482
# There are no NaNs in the array.
# There are no NaNs in the current_masses array at epoch 2.
# FreeFall Simulation redshift 10 - total mass of galaxy = 24.9482
# There are no NaNs in the array.
# There are no NaNs in the current_masses array at epoch 3.
# FreeFall Simulation redshift 10 - total mass of galaxy = 24.9482
# There are no NaNs in the array.
# There are no NaNs in the current_masses array at epoch 4.
# FreeFall Simulation redshift 10 - total mass of galaxy = 24.9482
# There are no NaNs in the array.
# There are no NaNs in the current_masses array at epoch 5.
# FreeFall Simulation redshift 10 - total mass of galaxy = 24.9482
# There are no NaNs in the array.
# There are no NaNs in the current_masses array at epoch 6.
# FreeFall Simulation redshift 10 - total mass of galaxy = 24.9482
# There are no NaNs in the array.
# There are no NaNs in the current_masses array at epoch 7.
# FreeFall Simulation redshift 10 - total mass of galaxy = 24.9482
# There are no NaNs in the array.
# There are no NaNs in the current_masses array at epoch 8.
# FreeFall Simulation redshift 10 - total mass of galaxy = 24.9482
# There are no NaNs in the array.
# There are no NaNs in the current_masses array at epoch 9.
# FreeFall Simulation redshift 10 - total mass of galaxy = 24.9482
# There are no NaNs in the array.
# There are no NaNs in the current_masses array at epoch 10.
# FreeFall Simulation redshift 10 - total mass of galaxy = 24.9482
# Relativistic Speed Reached: 0.541347
# Relativistic Speed Reached: 0.541346
# Relativistic Speed Reached: 0.541345
# Relativistic Speed Reached: 0.541343
# Relativistic Speed Reached: 0.541342
# Relativistic Speed Reached: 0.54134
# Relativistic Speed Reached: 0.541338
# Relativistic Speed Reached: 0.541335
# Relativistic Speed Reached: 0.541332
# Relativistic Speed Reached: 0.541328
# Relativistic Speed Reached: 0.541324
# Relativistic Speed Reached: 0.541318
# Relativistic Speed Reached: 0.541312
# Relativistic Speed Reached: 0.541304
# Relativistic Speed Reached: 0.541295
# Relativistic Speed Reached: 0.541284
# Relativistic Speed Reached: 0.541272
# Relativistic Speed Reached: 0.541256
# Relativistic Speed Reached: 0.541238
# Relativistic Speed Reached: 0.541216
# Relativistic Speed Reached: 0.541189
# Relativistic Speed Reached: 0.541158
# Relativistic Speed Reached: 0.54112
# Relativistic Speed Reached: 0.541076
# Relativistic Speed Reached: 0.541022
# Relativistic Speed Reached: 0.540958
# Relativistic Speed Reached: 0.540882
# Relativistic Speed Reached: 0.540792
# Relativistic Speed Reached: 0.540683
# Relativistic Speed Reached: 0.540554
# Relativistic Speed Reached: 0.5404
# Relativistic Speed Reached: 0.540216
# Relativistic Speed Reached: 0.539997
# Relativistic Speed Reached: 0.539736
# Relativistic Speed Reached: 0.539425
# Relativistic Speed Reached: 0.539054
# Relativistic Speed Reached: 0.538612
# Relativistic Speed Reached: 0.538087
# Relativistic Speed Reached: 0.537462
# Relativistic Speed Reached: 0.536718
# Relativistic Speed Reached: 0.535836
# Relativistic Speed Reached: 0.534788
# Relativistic Speed Reached: 0.533547
# Relativistic Speed Reached: 0.532077
# Relativistic Speed Reached: 0.530339
# Relativistic Speed Reached: 0.528288
# Relativistic Speed Reached: 0.525873
# Relativistic Speed Reached: 0.523035
# Relativistic Speed Reached: 0.51971
# Relativistic Speed Reached: 0.515824
# Relativistic Speed Reached: 0.511298
# Relativistic Speed Reached: 0.506048
# There are no NaNs in the array.
# There are no NaNs in the current_masses array at epoch 11.
# FreeFall Simulation redshift 10 - total mass of galaxy = 24.9482
# Relativistic Speed Reached: 0.590455
# Relativistic Speed Reached: 0.590454
# Relativistic Speed Reached: 0.590453
# Relativistic Speed Reached: 0.590452
# Relativistic Speed Reached: 0.59045
# Relativistic Speed Reached: 0.590448
# Relativistic Speed Reached: 0.590446
# Relativistic Speed Reached: 0.590443
# Relativistic Speed Reached: 0.590439
# Relativistic Speed Reached: 0.590435
# Relativistic Speed Reached: 0.59043
# Relativistic Speed Reached: 0.590425
# Relativistic Speed Reached: 0.590418
# Relativistic Speed Reached: 0.590409
# Relativistic Speed Reached: 0.590399
# Relativistic Speed Reached: 0.590388
# Relativistic Speed Reached: 0.590373
# Relativistic Speed Reached: 0.590357
# Relativistic Speed Reached: 0.590336
# Relativistic Speed Reached: 0.590312
# Relativistic Speed Reached: 0.590284
# Relativistic Speed Reached: 0.590249
# Relativistic Speed Reached: 0.590208
# Relativistic Speed Reached: 0.59016
# Relativistic Speed Reached: 0.590101
# Relativistic Speed Reached: 0.590032
# Relativistic Speed Reached: 0.589949
# Relativistic Speed Reached: 0.58985
# Relativistic Speed Reached: 0.589732
# Relativistic Speed Reached: 0.589591
# Relativistic Speed Reached: 0.589423
# Relativistic Speed Reached: 0.589222
# Relativistic Speed Reached: 0.588983
# Relativistic Speed Reached: 0.588698
# Relativistic Speed Reached: 0.588359
# Relativistic Speed Reached: 0.587955
# Relativistic Speed Reached: 0.587473
# Relativistic Speed Reached: 0.5869
# Relativistic Speed Reached: 0.586218
# Relativistic Speed Reached: 0.585407
# Relativistic Speed Reached: 0.584445
# Relativistic Speed Reached: 0.583302
# Relativistic Speed Reached: 0.581948
# Relativistic Speed Reached: 0.580344
# Relativistic Speed Reached: 0.578449
# Relativistic Speed Reached: 0.576212
# Relativistic Speed Reached: 0.573578
# Relativistic Speed Reached: 0.570483
# Relativistic Speed Reached: 0.566856
# Relativistic Speed Reached: 0.562617
# Relativistic Speed Reached: 0.557681
# Relativistic Speed Reached: 0.551954
# Relativistic Speed Reached: 0.545337
# Relativistic Speed Reached: 0.537728
# Relativistic Speed Reached: 0.529022
# Relativistic Speed Reached: 0.519116
# Relativistic Speed Reached: 0.507912
# There are no NaNs in the array.
# There are no NaNs in the current_masses array at epoch 12.
# FreeFall Simulation redshift 10 - total mass of galaxy = 24.9482
# Relativistic Speed Reached: 0.639547
# Relativistic Speed Reached: 0.639546
# Relativistic Speed Reached: 0.639544
# Relativistic Speed Reached: 0.639543
# Relativistic Speed Reached: 0.639541
# Relativistic Speed Reached: 0.639539
# Relativistic Speed Reached: 0.639536
# Relativistic Speed Reached: 0.639533
# Relativistic Speed Reached: 0.639529
# Relativistic Speed Reached: 0.639525
# Relativistic Speed Reached: 0.63952
# Relativistic Speed Reached: 0.639513
# Relativistic Speed Reached: 0.639506
# Relativistic Speed Reached: 0.639497
# Relativistic Speed Reached: 0.639486
# Relativistic Speed Reached: 0.639473
# Relativistic Speed Reached: 0.639458
# Relativistic Speed Reached: 0.63944
# Relativistic Speed Reached: 0.639418
# Relativistic Speed Reached: 0.639392
# Relativistic Speed Reached: 0.639361
# Relativistic Speed Reached: 0.639324
# Relativistic Speed Reached: 0.639279
# Relativistic Speed Reached: 0.639226
# Relativistic Speed Reached: 0.639163
# Relativistic Speed Reached: 0.639088
# Relativistic Speed Reached: 0.638998
# Relativistic Speed Reached: 0.638891
# Relativistic Speed Reached: 0.638763
# Relativistic Speed Reached: 0.63861
# Relativistic Speed Reached: 0.638428
# Relativistic Speed Reached: 0.638211
# Relativistic Speed Reached: 0.637952
# Relativistic Speed Reached: 0.637644
# Relativistic Speed Reached: 0.637276
# Relativistic Speed Reached: 0.636838
# Relativistic Speed Reached: 0.636316
# Relativistic Speed Reached: 0.635696
# Relativistic Speed Reached: 0.634957
# Relativistic Speed Reached: 0.634079
# Relativistic Speed Reached: 0.633036
# Relativistic Speed Reached: 0.631799
# Relativistic Speed Reached: 0.630332
# Relativistic Speed Reached: 0.628595
# Relativistic Speed Reached: 0.626542
# Relativistic Speed Reached: 0.62412
# Relativistic Speed Reached: 0.621266
# Relativistic Speed Reached: 0.617914
# Relativistic Speed Reached: 0.613985
# Relativistic Speed Reached: 0.609393
# Relativistic Speed Reached: 0.604047
# Relativistic Speed Reached: 0.597844
# Relativistic Speed Reached: 0.590677
# Relativistic Speed Reached: 0.582435
# Relativistic Speed Reached: 0.573005
# Relativistic Speed Reached: 0.562275
# Relativistic Speed Reached: 0.550139
# Relativistic Speed Reached: 0.536501
# Relativistic Speed Reached: 0.521281
# Relativistic Speed Reached: 0.50442
# There are no NaNs in the array.
# There are no NaNs in the current_masses array at epoch 13.
# FreeFall Simulation redshift 10 - total mass of galaxy = 24.9482
# Relativistic Speed Reached: 0.688621
# Relativistic Speed Reached: 0.68862
# Relativistic Speed Reached: 0.688618
# Relativistic Speed Reached: 0.688617
# Relativistic Speed Reached: 0.688615
# Relativistic Speed Reached: 0.688612
# Relativistic Speed Reached: 0.688609
# Relativistic Speed Reached: 0.688606
# Relativistic Speed Reached: 0.688602
# Relativistic Speed Reached: 0.688597
# Relativistic Speed Reached: 0.688592
# Relativistic Speed Reached: 0.688585
# Relativistic Speed Reached: 0.688577
# Relativistic Speed Reached: 0.688567
# Relativistic Speed Reached: 0.688555
# Relativistic Speed Reached: 0.688542
# Relativistic Speed Reached: 0.688525
# Relativistic Speed Reached: 0.688505
# Relativistic Speed Reached: 0.688482
# Relativistic Speed Reached: 0.688454
# Relativistic Speed Reached: 0.68842
# Relativistic Speed Reached: 0.68838
# Relativistic Speed Reached: 0.688333
# Relativistic Speed Reached: 0.688276
# Relativistic Speed Reached: 0.688208
# Relativistic Speed Reached: 0.688127
# Relativistic Speed Reached: 0.68803
# Relativistic Speed Reached: 0.687915
# Relativistic Speed Reached: 0.687777
# Relativistic Speed Reached: 0.687613
# Relativistic Speed Reached: 0.687417
# Relativistic Speed Reached: 0.687183
# Relativistic Speed Reached: 0.686904
# Relativistic Speed Reached: 0.686572
# Relativistic Speed Reached: 0.686176
# Relativistic Speed Reached: 0.685704
# Relativistic Speed Reached: 0.685143
# Relativistic Speed Reached: 0.684474
# Relativistic Speed Reached: 0.683679
# Relativistic Speed Reached: 0.682734
# Relativistic Speed Reached: 0.681611
# Relativistic Speed Reached: 0.680278
# Relativistic Speed Reached: 0.678699
# Relativistic Speed Reached: 0.676829
# Relativistic Speed Reached: 0.674618
# Relativistic Speed Reached: 0.67201
# Relativistic Speed Reached: 0.668938
# Relativistic Speed Reached: 0.665328
# Relativistic Speed Reached: 0.661097
# Relativistic Speed Reached: 0.656153
# Relativistic Speed Reached: 0.650396
# Relativistic Speed Reached: 0.643717
# Relativistic Speed Reached: 0.636
# Relativistic Speed Reached: 0.627126
# Relativistic Speed Reached: 0.616972
# Relativistic Speed Reached: 0.605419
# Relativistic Speed Reached: 0.592351
# Relativistic Speed Reached: 0.577667
# Relativistic Speed Reached: 0.561278
# Relativistic Speed Reached: 0.543123
# Relativistic Speed Reached: 0.523167
# Relativistic Speed Reached: 0.501412

# %%
import math
import numpy as np
import xarray as xr
import ipywidgets as widgets
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

suffix = "_8"
pd_r = np.load("./data/_freefall_all_r" + suffix + ".npy")
pd_z = np.load("./data/_freefall_all_z" + suffix + ".npy")
pd_dv0 = np.load("./data/_freefall_all_dv0" + suffix + ".npy")
epochs = np.load("./data/_freefall_epochs" + suffix + ".npy")
n_epochs = len(epochs)
Radius_4D=14.01e9
redshifts =np.load("./data/_freefall_redshifts" + suffix + ".npy")

# Load the dataset
data = np.load ("./data/_freefall_all_current_masses" + suffix + ".npy")
pd_masses = xr.DataArray(data).rename({ 'dim_0' : 'epoch', 'dim_1': 'radius', 'dim_2': 'elevation',})

def plot_2d_mass(z):
    fig = plt.figure(figsize=(10, 8))
    gs = gridspec.GridSpec(1, 2, width_ratios=[3, 1])
    
    R_0 = 14.01  # 4D radius of the Universe
    z_0 = redshifts[z]  # the initial redshift
    epoch_0 = epochs[z]
    
    # Create the 2D subplot
    ax = plt.subplot(gs[0])
    

    # Create a symmetric X grid by concatenating the negative and positive r values
    r_extended = np.concatenate((-pd_r[z][::-1], pd_r[z]))

    # Concatenate the values of pd_masses to make the mass symmetric along the radius
    mass_values_symmetric = np.concatenate((pd_masses[z].values[::-1, :], pd_masses[z].values), axis=0)

    # Check the shapes to understand the mismatch
    print("Shape of mass_values_symmetric:", mass_values_symmetric.shape)
    print("Shape of pd_z[z]:", pd_z[z].shape)
    print("Shape of r_extended:", r_extended.shape)

    # Create a new DataArray with symmetric values
    symmetric_mass = xr.DataArray(
        mass_values_symmetric, 
        coords={'radius': r_extended, 'elevation': pd_z[z]}, 
        dims=['radius', 'elevation']  # swap these dimensions
    )



    dv0 = pd_dv0[z][:, None]
    dv0_broadcasted = np.broadcast_to(dv0, pd_masses[z].values.shape)

    # Now, you can plot this symmetric_mass DataArray directly
    symmetric_mass.plot(ax=ax, x='radius', y='elevation', cmap='coolwarm')
    ax.set_title("$M_{33}$ Mass Profile\n" + "Redshift z ={} \n epoch {}".format(z_0,epoch_0/1E6)  )
    ax.set_xlabel('X (1000 Lyr)')
    ax.set_ylabel('Z (1000 Lyr)')

    # Remaining polar subplot code remains unchanged
    # Create the second subplot
    ax = plt.subplot(gs[1], projection='polar')  # 1 row, 2 columns, second subplot
    circle_outer = plt.Circle((0, 0), R_0, transform=ax.transData._b, fill = False)
    circle_inner = plt.Circle((0, 0), R_0/(1+z_0), transform=ax.transData._b, fill = False, linestyle='dashed')
    ax.add_artist(circle_outer)
    ax.add_artist(circle_inner)

    z_values = np.linspace(0, z_0, 100)
    R_values = R_0/(1+z_values)
    R_z0 =  R_0/(1+z_0)
    angle_0 = 1 - 1/(1+z_0)
    angle_values =  R_values/R_0
    ax.plot(np.pi/2-angle_0, R_z0, 'ro')
    ax.text(np.pi/2, R_0, 'Earth', horizontalalignment='right')
    ax.text((np.pi/2-angle_0)*0.92, R_z0, '$M_{33}$', horizontalalignment='left')
    ax.scatter(np.pi/2 - angle_0 + (R_values-R_z0)/R_0, R_values, color='b', s=0.5)
    ax.set_rmax(R_0)
    ax.set_rticks([])  # Less radial ticks
    ax.set_rlabel_position(-24.5)  # Move radial labels away from plotted line
    ax.grid(True)

    ax.set_title("$M_{33}$ Ancient Photon's path across \nthe Hyperspherical Universe", va='bottom')

    plt.subplots_adjust(wspace=0.3)
    plt.show()

z_slider = widgets.IntSlider(min=0, max=n_epochs-1, step=1, value=0, description='Redshift:', continuous_update=True)
interactive_plot = widgets.interactive_output(plot_2d_mass, {'z': z_slider})
display(z_slider, interactive_plot)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 9
#       6 import matplotlib.gridspec as gridspec
#       8 suffix = "_8"
# ----> 9 pd_r = np.load("./data/_freefall_all_r" + suffix + ".npy")
#      10 pd_z = np.load("./data/_freefall_all_z" + suffix + ".npy")
#      11 pd_dv0 = np.load("./data/_freefall_all_dv0" + suffix + ".npy")
#
# File ~/anaconda3/envs/Cosmos3020/lib/python3.11/site-packages/numpy/lib/npyio.py:427, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     425     own_fid = False
#     426 else:
# --> 427     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     428     own_fid = True
#     430 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: './data/_freefall_all_r_8.npy'

# %%
def plot_2d_mass(z):
    fig = plt.figure(figsize=(10, 8))
    gs = gridspec.GridSpec(1, 2, width_ratios=[3, 1])
    
    R_0 = 14.01  # 4D radius of the Universe
    z_0 = redshifts[z]  # the initial redshift
    
    # Create the 2D subplot
    ax = plt.subplot(gs[0])

    # Create a symmetric X grid by concatenating the negative and positive r values
    r_extended = np.concatenate((-pd_r[z][::-1], pd_r[z]))
    
    # Concatenate the values of pd_masses to make the mass symmetric along the radius
    mass_values_symmetric = np.concatenate((pd_masses[z].values[::-1, :], pd_masses[z].values), axis=0)

    # Calculate the density by dividing mass values by dv0
    dv0 = pd_dv0[z][:, None]
    r_exte4nded_squared = r_extended*r_extended
    r_exte4nded_squared = r_exte4nded_squared[:, None]
#     density_values_symmetric = np.log( mass_values_symmetric / r_exte4nded_squared ) #np.concatenate((dv0[::-1], dv0))
    density_values_symmetric = np.log( mass_values_symmetric / np.concatenate((dv0[::-1], dv0)) ) 

    
    # Create a new DataArray for symmetric density
    symmetric_density = xr.DataArray(
        density_values_symmetric, 
        coords={'radius': r_extended, 'elevation': pd_z[z]}, 
        dims=['radius', 'elevation']
    )

    # Now, you can plot this symmetric_density DataArray directly
    symmetric_density.plot(ax=ax, x='radius', y='elevation', cmap='coolwarm')
    ax.set_title("$M_{33}$ Density Profile\n Redshift z = %.2f" % z_0)
    ax.set_xlabel('X (Lyr)')
    ax.set_ylabel('Z (Lyr)')

    # Remaining polar subplot code remains unchanged
     # Create the second subplot
    ax = plt.subplot(gs[1], projection='polar')  # 1 row, 2 columns, second subplot
    circle_outer = plt.Circle((0, 0), R_0, transform=ax.transData._b, fill = False)
    circle_inner = plt.Circle((0, 0), R_0/(1+z_0), transform=ax.transData._b, fill = False, linestyle='dashed')
    ax.add_artist(circle_outer)
    ax.add_artist(circle_inner)

    z_values = np.linspace(0, z_0, 100)
    R_values = R_0/(1+z_values)
    R_z0 =  R_0/(1+z_0)
    angle_0 = 1 - 1/(1+z_0)
    angle_values =  R_values/R_0
    ax.plot(np.pi/2-angle_0, R_z0, 'ro')
    ax.text(np.pi/2, R_0, 'Earth', horizontalalignment='right')
    ax.text((np.pi/2-angle_0)*0.92, R_z0, '$M_{33}$', horizontalalignment='left')
    ax.scatter(np.pi/2 - angle_0 + (R_values-R_z0)/R_0, R_values, color='b', s=0.5)
    ax.set_rmax(R_0)
    ax.set_rticks([])  # Less radial ticks
    ax.set_rlabel_position(-24.5)  # Move radial labels away from plotted line
    ax.grid(True)

    ax.set_title("$M_{33}$ Ancient Photon's path across \nthe Hyperspherical Universe", va='bottom')
    plt.subplots_adjust(wspace=0.3)
    plt.show()

z_slider = widgets.IntSlider(min=0, max=n_epochs-1, step=1, value=0, description='Redshift:', continuous_update=False)
interactive_plot = widgets.interactive_output(plot_2d_mass, {'z': z_slider})
display(z_slider, interactive_plot)
# Out:
# IntSlider(value=0, continuous_update=False, description='Redshift:', max=14)
# Output()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import xarray as xr
import ipywidgets as widgets
from ipywidgets import interactive

suffix = "_10"
pd_r = np.load("./data/_freefall_all_r" + suffix + ".npy")
pd_z = np.load("./data/_freefall_all_z" + suffix + ".npy")
pd_dv0 = np.load("./data/_freefall_all_dv0" + suffix + ".npy")
epochs = np.load("./data/_freefall_epochs" + suffix + ".npy")
n_epochs = len(epochs)
Radius_4D=14.01e9
redshifts =np.load("./data/_freefall_redshifts" + suffix + ".npy")

# Load the dataset
data = np.load ("./data/_freefall_all_current_masses" + suffix + ".npy")
pd_masses = xr.DataArray(data).rename({ 'dim_0' : 'epoch', 'dim_1': 'radius', 'dim_2': 'elevation',})
n_epochs = len(epochs)

def update_density_range(z):
    min_density = np.log( np.min(pd_masses[z].values / pd_dv0[z][:, None]) +1E-5 )
    max_density = np.log( np.max(pd_masses[z].values / pd_dv0[z][:, None]) )
    if (min_density > max_density):
        a = max_density
        max_density = min_density
        min_density = a
    density_range_slider.max = max_density
    density_range_slider.min = min_density
    density_range_slider.value = [min_density, max_density]
    density_range_slider.step = (max_density - min_density) / 100

def plot_2d_mass(z, density_range):
    fig = plt.figure(figsize=(10, 8))
    gs = gridspec.GridSpec(1, 2, width_ratios=[3, 1])
    
    R_0 = 14.01  # 4D radius of the Universe
    z_0 = redshifts[z]  # the initial redshift
    print(z_0)
    # Create the 2D subplot
    ax = plt.subplot(gs[0])

    # Create a symmetric X grid by concatenating the negative and positive r values
    r_extended = np.concatenate((-pd_r[z][::-1], pd_r[z]))

    # Concatenate the values of pd_masses to make the mass symmetric along the radius
    mass_values_symmetric = np.concatenate((pd_masses[z].values[::-1, :], pd_masses[z].values), axis=0)

    # Calculate the density by dividing mass values by dv0
    dv0 = pd_dv0[z][:, None]
    density_values_symmetric = mass_values_symmetric / np.concatenate((dv0[::-1], dv0))

    # Create a new DataArray for symmetric density
    symmetric_density = xr.DataArray(
        density_values_symmetric, 
        coords={'radius': r_extended, 'elevation': pd_z[z]}, 
        dims=['radius', 'elevation']
    )

    # Now, you can plot this symmetric_density DataArray directly
    symmetric_density.plot(ax=ax, x='radius', y='elevation', cmap='coolwarm', vmin=density_range[0], vmax=density_range[1])
    ax.set_title("$M_{33}$ Luminous Density Profile\n Redshift z = %.2f" % z_0)
    ax.set_xlabel('X (1000 Lyr)')
    ax.set_ylabel('Z (1000 Lyr)')

    # Remaining polar subplot code remains unchanged
    # Create the second subplot
    ax = plt.subplot(gs[1], projection='polar')  # 1 row, 2 columns, second subplot
    circle_outer = plt.Circle((0, 0), R_0, transform=ax.transData._b, fill = False)
    circle_inner = plt.Circle((0, 0), R_0/(1+z_0), transform=ax.transData._b, fill = False, linestyle='dashed')
    ax.add_artist(circle_outer)
    ax.add_artist(circle_inner)

    z_values = np.linspace(0, z_0, 100)
    R_values = R_0/(1+z_values)
    R_z0 =  R_0/(1+z_0)
    angle_0 = 1 - 1/(1+z_0)
    angle_values =  R_values/R_0
    ax.plot(np.pi/2-angle_0, R_z0, 'ro')
    ax.text(np.pi/2, R_0, 'Earth', horizontalalignment='right')
    ax.text((np.pi/2-angle_0)*0.92, R_z0, '$M_{33}$', horizontalalignment='left')
    ax.scatter(np.pi/2 - angle_0 + (R_values-R_z0)/R_0, R_values, color='b', s=0.5)
    ax.set_rmax(R_0)
    ax.set_rticks([])  # Less radial ticks
    ax.set_rlabel_position(-24.5)  # Move radial labels away from plotted line
    ax.grid(True)

    ax.set_title("$M_{33}$ Ancient Photon's path across \nthe Hyperspherical Universe", va='bottom')

    plt.subplots_adjust(wspace=0.3)
    plt.show()



# Slider for redshift
z_slider = widgets.IntSlider(min=0, max=n_epochs-1, step=1, value=0, description='Redshift:', continuous_update=False)

# Slider for density range (initialize with dummy values; they'll be updated by the function)
density_range_slider = widgets.FloatRangeSlider(
    value=[0, 1],
    min=0,
    max=1,
    step=0.01,
    description='Density Range:',
    continuous_update=False
)

def on_z_slider_change(change):
    if change['name'] == 'value':
        update_density_range(change['new'])

z_slider.observe(on_z_slider_change)

interactive_plot = widgets.interactive_output(plot_2d_mass, {'z': z_slider, 'density_range': density_range_slider})
display(z_slider, density_range_slider, interactive_plot)

# Trigger the initial update
update_density_range(z_slider.value)
# Out:
# 10.007857142857143
